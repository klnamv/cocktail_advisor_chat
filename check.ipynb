# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data/Cocktails Final.csv', index_col=0)
data.head()
# Out:
#    id  name  alcoholic        category       glassType  \
# 0   0    A1  Alcoholic        Cocktail  Cocktail glass
# 1   1   ABC  Alcoholic            Shot      Shot glass
# 2   2   Ace  Alcoholic        Cocktail   Martini Glass
# 3   3  ACID  Alcoholic            Shot      Shot glass
# 4   4  Adam  Alcoholic  Ordinary Drink  Cocktail glass
#
#                                         instructions  \
# 0  Pour all ingredients into a cocktail shaker, m...
# 1                           Layered in a shot glass.
# 2  Shake all the ingredients in a cocktail shaker...
# 3  Poor in the 151 first followed by the 101 serv...
# 4  In a shaker half-filled with ice cubes, combin...
#
#                                       drinkThumbnail  \
# 0  https://www.thecocktaildb.com/images/media/dri...
# 1  https://www.thecocktaildb.com/images/media/dri...
# 2  https://www.thecocktaildb.com/images/media/dri...
# 3  https://www.thecocktaildb.com/images/media/dri...
# ...

# %%
data
# Out:
#       id                      name  alcoholic             category  \
# 0      0                        A1  Alcoholic             Cocktail
# 1      1                       ABC  Alcoholic                 Shot
# 2      2                       Ace  Alcoholic             Cocktail
# 3      3                      ACID  Alcoholic                 Shot
# 4      4                      Adam  Alcoholic       Ordinary Drink
# ..   ...                       ...        ...                  ...
# 420  420              Zima Blaster  Alcoholic       Ordinary Drink
# 421  421            Zizi Coin-coin  Alcoholic  Punch / Party Drink
# 422  422           Zimadori Zinger  Alcoholic  Punch / Party Drink
# 423  423           Zippy's Revenge  Alcoholic             Cocktail
# 424  424  Ziemes Martini Apfelsaft  Alcoholic       Ordinary Drink
#
#                     glassType  \
# 0              Cocktail glass
# 1                  Shot glass
# 2               Martini Glass
# 3                  Shot glass
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 425 entries, 0 to 424
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  425 non-null    int64
#  1   name                425 non-null    object
#  2   alcoholic           425 non-null    object
#  3   category            425 non-null    object
#  4   glassType           425 non-null    object
#  5   instructions        425 non-null    object
#  6   drinkThumbnail      425 non-null    object
#  7   ingredients         425 non-null    object
#  8   ingredientMeasures  425 non-null    object
#  9   text                425 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 36.5+ KB

# %% [markdown]
# # Check mising data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 425 entries, 0 to 424
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  425 non-null    int64
#  1   name                425 non-null    object
#  2   alcoholic           425 non-null    object
#  3   category            425 non-null    object
#  4   glassType           425 non-null    object
#  5   instructions        425 non-null    object
#  6   drinkThumbnail      425 non-null    object
#  7   ingredients         425 non-null    object
#  8   ingredientMeasures  425 non-null    object
#  9   text                425 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 36.5+ KB

# %%
data.describe()
# Out:
#                id
# count  425.000000
# mean   212.000000
# std    122.831185
# min      0.000000
# 25%    106.000000
# 50%    212.000000
# 75%    318.000000
# max    424.000000

# %%
print(data.isnull().sum())
# Out:
# id                    0
# name                  0
# alcoholic             0
# category              0
# glassType             0
# instructions          0
# drinkThumbnail        0
# ingredients           0
# ingredientMeasures    0
# text                  0
# dtype: int64

# %% [markdown]
# # Check Sugar and Non Sugar Coctails

# %%
data['ingredients']
# Out:
# 0      ['Gin', 'Grand Marnier', 'Lemon Juice', 'Grena...
# 1          ['Amaretto', 'Baileys irish cream', 'Cognac']
# 2      ['Gin', 'Grenadine', 'Heavy cream', 'Milk', 'E...
# 3                       ['151 proof rum', 'Wild Turkey']
# 4               ['Dark rum', 'Lemon juice', 'Grenadine']
#                              ...
# 420               ['Zima', 'Chambord raspberry liqueur']
# 421         ['Cointreau', 'Lemon juice', 'Ice', 'Lemon']
# 422                     ['Midori melon liqueur', 'Zima']
# 423                      ['Amaretto', 'Rum', 'Kool-Aid']
# 424                          ['Vermouth', 'Apple juice']
# Name: ingredients, Length: 425, dtype: object

# %%
data['category'].unique()
# Out:
# array(['Cocktail', 'Shot', 'Ordinary Drink', 'Other / Unknown',
#        'Coffee / Tea', 'Beer', 'Punch / Party Drink', 'Shake',
#        'Soft Drink', 'Homemade Liqueur', 'Cocoa'], dtype=object)

# %%
sugar_cocktails = data[data['ingredients'].str.contains('Sugar', case=False, na=False)]
sugar_cocktails
# Out:
#       id              name      alcoholic        category  \
# 14    14          Acapulco      Alcoholic  Ordinary Drink
# 31    31           Bramble      Alcoholic  Ordinary Drink
# 48    48       Boston Sour      Alcoholic  Ordinary Drink
# 52    52        Caipirinha      Alcoholic  Ordinary Drink
# 61    61      Caipirissima      Alcoholic  Ordinary Drink
# ..   ...               ...            ...             ...
# 380  380  Thai Iced Coffee  Non alcoholic    Coffee / Tea
# 385  385           Vampiro      Alcoholic  Ordinary Drink
# 386  386           Vesuvio      Alcoholic  Ordinary Drink
# 396  396   Victory Collins      Alcoholic  Ordinary Drink
# 404  404      Whiskey Sour      Alcoholic  Ordinary Drink
#
#                glassType                                       instructions  \
# 14   Old-fashioned glass  Combine and shake all ingredients (except mint...
# 31   Old-Fashioned glass  Fill glass with crushed ice. Build gin, lemon ...
# ...

# %%
non_sugar_coctails = data[~data['ingredients'].str.contains('Sugar', case=False, na=False)]
non_sugar_coctails
# Out:
#       id                      name  alcoholic             category  \
# 0      0                        A1  Alcoholic             Cocktail
# 1      1                       ABC  Alcoholic                 Shot
# 2      2                       Ace  Alcoholic             Cocktail
# 3      3                      ACID  Alcoholic                 Shot
# 4      4                      Adam  Alcoholic       Ordinary Drink
# ..   ...                       ...        ...                  ...
# 420  420              Zima Blaster  Alcoholic       Ordinary Drink
# 421  421            Zizi Coin-coin  Alcoholic  Punch / Party Drink
# 422  422           Zimadori Zinger  Alcoholic  Punch / Party Drink
# 423  423           Zippy's Revenge  Alcoholic             Cocktail
# 424  424  Ziemes Martini Apfelsaft  Alcoholic       Ordinary Drink
#
#                     glassType  \
# 0              Cocktail glass
# 1                  Shot glass
# 2               Martini Glass
# 3                  Shot glass
# ...

# %%
non_alcohol_sugar_cocktails = data[(data['alcoholic'].str.lower() == 'non alcoholic') & (data['ingredients'].str.contains('Sugar', case=False, na=False))]
non_alcohol_sugar_cocktails[['alcoholic', 'ingredients']]
# Out:
#          alcoholic                                        ingredients
# 74   Non alcoholic  ['Cranberry juice', 'Sugar', 'Pineapple juice'...
# 104  Non alcoholic                        ['Coffee', 'Milk', 'Sugar']
# 110  Non alcoholic  ['Apple juice', 'Strawberries', 'Sugar', 'Lemo...
# 169  Non alcoholic  ['Lime', 'Brown sugar', 'Passion fruit juice',...
# 171  Non alcoholic               ['Coffee', 'Sugar', 'Water', 'Milk']
# 209  Non alcoholic       ['Lime', 'Sugar', 'Soda water', 'Lime peel']
# 215  Non alcoholic        ['Yoghurt', 'Ice', 'Sugar', 'Lime', 'Salt']
# 216  Non alcoholic  ['Ginger', 'Water', 'Lemon', 'Sugar', 'Cayenne...
# 219  Non alcoholic             ['Mango', 'Yoghurt', 'Sugar', 'Water']
# 220  Non alcoholic  ['Yoghurt', 'Water', 'Sugar', 'Salt', 'Lemon j...
# 247  Non alcoholic  ['Water', 'Tea', 'Ginger', 'Cardamom', 'Cloves...
# 261  Non alcoholic  ['Cocoa powder', 'Sugar', 'Vanilla extract', '...
# ...
